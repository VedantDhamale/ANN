# %%
import numpy as np

# %%
x=np.array([[0,0],[0,1],[1,0],[1,1]])
y=np.array([[0],[1],[1],[0]])

#input layer neuron
IL=2

#hidden layer neuron
HL=2

#output layer neuron
OL=1

epochs = 1000
lr = 0.1

# %%
def sigmoid_fun(x):
    sigmoid_val=1/(1+np.exp(-x))
    return sigmoid_val

def sigmoid_derivative(x):
    return x * (1 - x)

# %%
HW = np.random.uniform(size=(IL,HL))
hidden_bias =np.random.uniform(size=(1,HL))

print("Hidden layer Weights")
print(HW)
print(" ")

print("Hidden layer bias")
print(hidden_bias)
print(" ")

OW = np.random.uniform(size=(HL,OL))
output_bias = np.random.uniform(size=(1,OL))

print("Output layer Weights")
print(OW)
print(" ")

print("Output layer bias")
print(output_bias)
# Out:
# Hidden layer Weights
# [[0.68620398 0.60274516]
#  [0.62952534 0.98560933]]
#
# Hidden layer bias
# [[0.74152031 0.24887387]]
#
# Output layer Weights
# [[0.9536065 ]
#  [0.79281925]]
#
# Output layer bias
# [[0.12981309]]

# %%
#for hidden layer

print("Aggrigation in hidden layer")
#doing aggrigation
HL_activation = np.dot(x,HW)
HL_activation += hidden_bias
print(HL_activation)
print(" ")

print("Applying Activation in Hidden layer")
#applying activation function
hidden_layer_output = sigmoid_fun(HL_activation)
print(hidden_layer_output)


print(" ")


#for output layer
#doing aggrigation
print("Aggrigation in Output Layer")
OL_activation=np.dot(hidden_layer_output,OW)
OL_activation += output_bias
print(OL_activation)


print(" ")
#applying activation 
print("Applying Activation Function in Output layer")
print("Predicated Output")
Predicted_Output = sigmoid_fun(OL_activation)
print(Predicted_Output)
# Out:
# Aggrigation in hidden layer
# [[0.74152031 0.24887387]
#  [1.37104565 1.23448319]
#  [1.42772429 0.85161902]
#  [2.05724963 1.83722835]]
#
# Applying Activation in Hidden layer
# [[0.67732822 0.5618993 ]
#  [0.79754904 0.77460227]
#  [0.80654649 0.70090666]
#  [0.88667811 0.86262058]]
#
# Aggrigation in Output Layer
# [[1.22120227]
#  [1.50448064]
#  [1.45463336]
#  [1.6592573 ]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.77227506]
#  [0.8182418 ]
#  [0.81071049]
#  [0.84013828]]

# %%
error = y - Predicted_Output
print("Error",error)
# Out:
# Error [[-0.77227506]
#  [ 0.1817582 ]
#  [ 0.18928951]
#  [-0.84013828]]

# %%
for epoch in range(epochs):
    #for hidden layer

    print("Aggrigation in hidden layer")
    #doing aggrigation
    HL_activation = np.dot(x,HW)
    HL_activation += hidden_bias
    print(HL_activation)
    print(" ")

    print("Applying Activation in Hidden layer")
    #applying activation function
    hidden_layer_output = sigmoid_fun(HL_activation)
    print(hidden_layer_output)


    print(" ")


    #for output layer
    #doing aggrigation
    print("Aggrigation in Output Layer")
    OL_activation=np.dot(hidden_layer_output,OW)
    OL_activation += output_bias
    print(OL_activation)


    print(" ")
    #applying activation 
    print("Applying Activation Function in Output layer")
    print("Predicated Output")
    Predicted_Output = sigmoid_fun(OL_activation)
    print(Predicted_Output)
    
    error = y - Predicted_Output
    print("Error",error)
    
    d_predicted_output = error * sigmoid_derivative(Predicted_Output)
    error_hidden_layer = d_predicted_output.dot(OW.T)
    d_hidden_layer = error_hidden_layer * sigmoid_derivative(hidden_layer_output)

    #Updating Weights and Biases
    OW += hidden_layer_output.T.dot(d_predicted_output) * lr
    output_bias += np.sum(d_predicted_output,axis=0,keepdims=True) * lr
    HW += x.T.dot(d_hidden_layer) * lr
    hidden_bias += np.sum(d_hidden_layer,axis=0,keepdims=True) * lr
# Out:
# Aggrigation in hidden layer
# [[0.74152031 0.24887387]
#  [1.37104565 1.23448319]
#  [1.42772429 0.85161902]
#  [2.05724963 1.83722835]]
#
# Applying Activation in Hidden layer
# [[0.67732822 0.5618993 ]
#  [0.79754904 0.77460227]
#  [0.80654649 0.70090666]
#  [0.88667811 0.86262058]]
#
# Aggrigation in Output Layer
# [[1.22120227]
#  [1.50448064]
#  [1.45463336]
#  [1.6592573 ]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.77227506]
#  [0.8182418 ]
#  [0.81071049]
#  [0.84013828]]
# Error [[-0.77227506]
#  [ 0.1817582 ]
#  [ 0.18928951]
#  [-0.84013828]]
# Aggrigation in hidden layer
# [[0.73845693 0.24601999]
#  [1.36731731 1.23094336]
#  [1.42401194 0.8481878 ]
#  [2.05287233 1.83311117]]
#
# Applying Activation in Hidden layer
# [[0.67665834 0.56119664]
#  [0.79694638 0.77398364]
#  [0.80596659 0.70018685]
#  [0.88623753 0.86213194]]
#
# Aggrigation in Output Layer
# [[1.18337105]
#  [1.46219499]
#  [1.41313327]
#  [1.61474956]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.76555339]
#  [0.81186816]
#  [0.80425967]
#  [0.83406976]]
# Error [[-0.76555339]
#  [ 0.18813184]
#  [ 0.19574033]
#  [-0.83406976]]
# Aggrigation in hidden layer
# [[0.73543069 0.24320873]
#  [1.36363496 1.22745434]
#  [1.42034546 0.84481121]
#  [2.04854973 1.82905683]]
#
# Applying Activation in Hidden layer
# [[0.67599587 0.56050424]
#  [0.79634984 0.77337271]
#  [0.80539257 0.69947754]
#  [0.885801   0.86164933]]
#
# Aggrigation in Output Layer
# [[1.14546284]
#  [1.41980935]
#  [1.37154008]
#  [1.57012201]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.75868121]
#  [0.80530853]
#  [0.79762886]
#  [0.827801  ]]
# Error [[-0.75868121]
#  [ 0.19469147]
#  [ 0.20237114]
#  [-0.827801  ]]
# Aggrigation in hidden layer
# [[0.73244668 0.24044489]
#  [1.36000532 1.22402254]
#  [1.41673149 0.84149564]
#  [2.04429013 1.82507329]]
#
# Applying Activation in Hidden layer
# [[0.67534195 0.55982328]
#  [0.79576056 0.77277067]
#  [0.80482551 0.69878012]
#  [0.8853694  0.86117377]]
#
# Aggrigation in Output Layer
# [[1.10753394]
#  [1.37738705]
#  [1.32991585]
#  [1.52544148]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.75166908]
#  [0.79857102]
#  [0.79082672]
#  [0.82133837]]
# Error [[-0.75166908]
#  [ 0.20142898]
#  [ 0.20917328]
#  [-0.82133837]]
# Aggrigation in hidden layer
# [[0.72950994 0.23773324]
#  [1.35643512 1.2206543 ]
#  [1.41317667 0.8382474 ]
#  [2.04010185 1.82116846]]
#
# Applying Activation in Hidden layer
# [[0.67469772 0.55915497]
#  [0.7951797  0.77217867]
#  [0.8042665  0.69809597]
#  [0.88494364 0.86070627]]
#
# Aggrigation in Output Layer
# [[1.06964384]
#  [1.33499507]
#  [1.28832624]
#  [1.48077877]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.74452918]
#  [0.79166568]
#  [0.78386375]
#  [0.81469018]]
# Error [[-0.74452918]
#  [ 0.20833432]
#  [ 0.21613625]
#  [-0.81469018]]
# Aggrigation in hidden layer
# [[0.72662548 0.23507841]
#  [1.352931   1.21735587]
#  [1.4096876  0.8350727 ]
#  [2.03599312 1.81735015]]
#
# Applying Activation in Hidden layer
# [[0.67406432 0.55850045]
#  [0.7946084  0.7715979 ]
#  [0.80371667 0.69742646]
#  [0.88452463 0.86024786]]
#
# Aggrigation in Output Layer
# [[1.03185475]
#  [1.29270354]
#  [1.24683993]
#  [1.4362081 ]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.73727532]
#  [0.78460444]
#  [0.77675236]
#  [0.80786677]]
# Error [[-0.73727532]
#  [ 0.21539556]
#  [ 0.22324764]
#  [-0.80786677]]
# Aggrigation in hidden layer
# [[0.72379813 0.23248488]
#  [1.34949948 1.21413328]
#  [1.4062707  0.83197753]
#  [2.03197205 1.81362593]]
#
# Applying Activation in Hidden layer
# [[0.67344284 0.55786084]
#  [0.79404779 0.77102947]
#  [0.80317707 0.69677291]
#  [0.88411328 0.85979953]]
#
# Aggrigation in Output Layer
# [[0.99423114]
#  [1.25058519]
#  [1.20552813]
#  [1.39180649]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.72992284]
#  [0.77740114]
#  [0.76950675]
#  [0.80088048]]
# Error [[-0.72992284]
#  [ 0.22259886]
#  [ 0.23049325]
#  [-0.80088048]]
# Aggrigation in hidden layer
# [[0.72103255 0.22995687]
#  [1.34614683 1.21099233]
#  [1.40293217 0.82896758]
#  [2.02804645 1.81000304]]
#
# Applying Activation in Hidden layer
# [[0.67283435 0.55723721]
#  [0.79349897 0.77047448]
#  [0.80264877 0.69613659]
#  [0.88371047 0.85936224]]
#
# Aggrigation in Output Layer
# [[0.95683909]
#  [1.20871464]
#  [1.16446388]
#  [1.34765309]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.72248849]
#  [0.77007144]
#  [0.76214288]
#  [0.79374567]]
# Error [[-0.72248849]
#  [ 0.22992856]
#  [ 0.23785712]
#  [-0.79374567]]
# Aggrigation in hidden layer
# [[0.71833313 0.22749835]
#  [1.34287902 1.20793846]
#  [1.39967791 0.82604819]
#  [2.02422381 1.80648831]]
#
# Applying Activation in Hidden layer
# [[0.67223985 0.55663055]
#  [0.792963   0.76993398]
#  [0.80213277 0.69551869]
#  [0.88331705 0.85893692]]
#
# Aggrigation in Output Layer
# [[0.91974561]
#  [1.16716765]
#  [1.12372129]
#  [1.30382832]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.71499027]
#  [0.76263267]
#  [0.75467833]
#  [0.78647858]]
# Error [[-0.71499027]
#  [ 0.23736733]
#  [ 0.24532167]
#  [-0.78647858]]
# Aggrigation in hidden layer
# [[0.71570395 0.2251129 ]
#  [1.33970163 1.20497667]
#  [1.39651342 0.82322425]
#  [2.02051109 1.80308802]]
#
# Applying Activation in Hidden layer
# [[0.6716603  0.55604176]
#  [0.79244087 0.76940892]
#  [0.80163004 0.69492033]
#  [0.88293385 0.85852442]]
#
# Aggrigation in Output Layer
# [[0.88301795]
#  [1.12602026]
#  [1.08337474]
#  [1.26041299]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.70744722]
#  [0.7551037 ]
#  [0.74713209]
#  [0.77909719]]
# Error [[-0.70744722]
#  [ 0.2448963 ]
#  [ 0.25286791]
#  [-0.77909719]]
# Aggrigation in hidden layer
# [[0.71314873 0.22280375]
#  [1.33661975 1.20211149]
#  [1.39344372 0.82050015]
#  [2.01691474 1.79980789]]
#
# Applying Activation in Hidden layer
# [[0.67109654 0.55547165]
#  [0.79193351 0.76890019]
#  [0.80114144 0.6943425 ]
#  [0.88256161 0.85812555]]
#
# Aggrigation in Output Layer
# [[0.84672276]
#  [1.08534795]
#  [1.043498  ]
#  [1.21748739]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.69987922]
#  [0.7475047 ]
#  [0.73952438]
#  [0.77162107]]
# Error [[-0.69987922]
#  [ 0.2524953 ]
#  [ 0.26047562]
#  [-0.77162107]]
# Aggrigation in hidden layer
# [[0.71067075 0.22057368]
#  [1.33363797 1.1993469 ]
#  [1.39047331 0.81787969]
#  [2.01344053 1.79665291]]
#
# Applying Activation in Hidden layer
# [[0.67054935 0.55492093]
#  [0.79144176 0.76840858]
#  [0.80066779 0.69378607]
#  [0.88220104 0.85774101]]
#
# Aggrigation in Output Layer
# [[0.81092534]
#  [1.04522472]
#  [1.00416338]
#  [1.1751303 ]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.69230665]
#  [0.73985686]
#  [0.73187636]
#  [0.76407109]]
# Error [[-0.69230665]
#  [ 0.26014314]
#  [ 0.26812364]
#  [-0.76407109]]
# Aggrigation in hidden layer
# [[0.70827286 0.21842499]
#  [1.33076024 1.19668625]
#  [1.38760612 0.81536606]
#  [2.0100935  1.79362733]]
#
# Applying Activation in Hidden layer
# [[0.67001941 0.55439017]
#  [0.79096636 0.76793476]
#  [0.8002098  0.6932518 ]
#  [0.88185276 0.85737142]]
#
# Aggrigation in Output Layer
# [[0.77568881]
#  [1.00572215]
#  [0.96544081]
#  [1.13341807]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.68475021]
#  [0.73218213]
#  [0.72420982]
#  [0.75646914]]
# Error [[-0.68475021]
#  [ 0.26781787]
#  [ 0.27579018]
#  [-0.75646914]]
# Aggrigation in hidden layer
# [[0.70595739 0.2163595 ]
#  [1.32798991 1.19413229]
#  [1.3848454  0.81296181]
#  [2.00687793 1.7907346 ]]
#
# Applying Activation in Hidden layer
# [[0.66950728 0.55387986]
#  [0.79050795 0.76747931]
#  [0.79976807 0.69274029]
#  [0.88151733 0.85701732]]
#
# Aggrigation in Output Layer
# [[0.74107336]
#  [0.96690859]
#  [0.92739703]
#  [1.09242364]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.67723053]
#  [0.72450289]
#  [0.7165469 ]
#  [0.74883783]]
# Error [[-0.67723053]
#  [ 0.27549711]
#  [ 0.2834531 ]
#  [-0.74883783]]
# Aggrigation in hidden layer
# [[0.70372618 0.21437852]
#  [1.32532964 1.19168706]
#  [1.38219378 0.81066879]
#  [2.00379723 1.78797734]]
#
# Applying Activation in Hidden layer
# [[0.6690134  0.55339031]
#  [0.79006705 0.76704266]
#  [0.7993431  0.692252  ]
#  [0.88119519 0.85667911]]
#
# Aggrigation in Output Layer
# [[0.70713557]
#  [0.92884832]
#  [0.89009476]
#  [1.0522157 ]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.66976792]
#  [0.71684158]
#  [0.70890973]
#  [0.74120015]]
# Error [[-0.66976792]
#  [ 0.28315842]
#  [ 0.29109027]
#  [-0.74120015]]
# Aggrigation in hidden layer
# [[0.70158055 0.21248284]
#  [1.32278138 1.18935196]
#  [1.37965317 0.80848819]
#  [2.000854   1.7853573 ]]
#
# Applying Activation in Hidden layer
# [[0.66853811 0.55292175]
#  [0.78964408 0.76662514]
#  [0.79893529 0.69178725]
#  [0.88088671 0.85635712]]
#
# Aggrigation in Output Layer
# [[0.67392771]
#  [0.89160083]
#  [0.85359203]
#  [1.01285793]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.66238208]
#  [0.70922042]
#  [0.70132011]
#  [0.73357908]]
# Error [[-0.66238208]
#  [ 0.29077958]
#  [ 0.29867989]
#  [-0.73357908]]
# Aggrigation in hidden layer
# [[0.69952129 0.21067277]
#  [1.32034641 1.18712768]
#  [1.37722481 0.8064205 ]
#  [1.99804993 1.7828754 ]]
#
# Applying Activation in Hidden layer
# [[0.66808163 0.55247426]
#  [0.78923934 0.76622696]
#  [0.79854492 0.69134621]
#  [0.88059218 0.85605156]]
#
# Aggrigation in Output Layer
# [[0.64149723]
#  [0.8552202 ]
#  [0.81794156]
#  [0.97440828]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.65509183]
#  [0.70166105]
#  [0.69379922]
#  [0.72599729]]
# Error [[-0.65509183]
#  [ 0.29833895]
#  [ 0.30620078]
#  [-0.72599729]]
# Aggrigation in hidden layer
# [[0.69754869 0.20894811]
#  [1.31802533 1.18501428]
#  [1.37490927 0.80446555]
#  [1.9953859  1.78053172]]
#
# Applying Activation in Hidden layer
# [[0.66764406 0.5520478 ]
#  [0.78885298 0.76584819]
#  [0.79817216 0.69092889]
#  [0.88031178 0.85576251]]
#
# Aggrigation in Output Layer
# [[0.60988635]
#  [0.81975459]
#  [0.78319027]
#  [0.93691849]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.64791488]
#  [0.69418424]
#  [0.68636728]
#  [0.71847679]]
# Error [[-0.64791488]
#  [ 0.30581576]
#  [ 0.31363272]
#  [-0.71847679]]
# Aggrigation in hidden layer
# [[0.69566255 0.20730819]
#  [1.31581804 1.18301119]
#  [1.37270644 0.80262256]
#  [1.99286194 1.77832556]]
#
# Applying Activation in Hidden layer
# [[0.6672254  0.55164223]
#  [0.7884851  0.76548879]
#  [0.79781707 0.69053519]
#  [0.88004559 0.85548998]]
#
# Aggrigation in Output Layer
# [[0.57913168]
#  [0.78524587]
#  [0.74937891]
#  [0.90043364]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.64086758]
#  [0.68680962]
#  [0.67904335]
#  [0.71103861]]
# Error [[-0.64086758]
#  [ 0.31319038]
#  [ 0.32095665]
#  [-0.71103861]]
# Aggrigation in hidden layer
# [[0.69386219 0.20575193]
#  [1.31372386 1.18111725]
#  [1.37061562 0.80089015]
#  [1.99047729 1.77625547]]
#
# Applying Activation in Hidden layer
# [[0.66682554 0.55125728]
#  [0.78813562 0.76514863]
#  [0.7974796  0.69016486]
#  [0.87979362 0.85523388]]
#
# Aggrigation in Output Layer
# [[0.54926407]
#  [0.75172941]
#  [0.71654188]
#  [0.86499191]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.63396483]
#  [0.67955541]
#  [0.67184506]
#  [0.70370255]]
# Error [[-0.63396483]
#  [ 0.32044459]
#  [ 0.32815494]
#  [-0.70370255]]
# Aggrigation in hidden layer
# [[0.69214654 0.20427786]
#  [1.31174149 1.17933075]
#  [1.36863553 0.79926642]
#  [1.98823048 1.77431932]]
#
# Applying Activation in Hidden layer
# [[0.66644427 0.55089261]
#  [0.78780442 0.76482745]
#  [0.79715961 0.68981754]
#  [0.8795558  0.854994  ]]
#
# Aggrigation in Output Layer
# [[0.52030849]
#  [0.71923396]
#  [0.68470708]
#  [0.83062449]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.6272199 ]
#  [0.67243831]
#  [0.66478846]
#  [0.69648696]]
# Error [[-0.6272199 ]
#  [ 0.32756169]
#  [ 0.33521154]
#  [-0.69648696]]
# Aggrigation in hidden layer
# [[0.69051412 0.20288414]
#  [1.30986913 1.17764951]
#  [1.36676436 0.797749  ]
#  [1.98611936 1.77251437]]
#
# Applying Activation in Hidden layer
# [[0.66608129 0.55054777]
#  [0.78749126 0.76452492]
#  [0.79685688 0.68949276]
#  [0.87933198 0.85477008]]
#
# Aggrigation in Output Layer
# [[0.49228409]
#  [0.68778168]
#  [0.65389598]
#  [0.79735554]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.62064436]
#  [0.66547327]
#  [0.65788787]
#  [0.68940852]]
# Error [[-0.62064436]
#  [ 0.33452673]
#  [ 0.34211213]
#  [-0.68940852]]
# Aggrigation in hidden layer
# [[0.68896313 0.20156866]
#  [1.30810451 1.17607094]
#  [1.36499984 0.79633508]
#  [1.98414122 1.77083736]]
#
# Applying Activation in Hidden layer
# [[0.66573623 0.55022224]
#  [0.7871958  0.76424061]
#  [0.7965711  0.68918997]
#  [0.87912193 0.85456177]]
#
# Aggrigation in Output Layer
# [[0.46520434]
#  [0.65738832]
#  [0.62412376]
#  [0.76520244]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.61424806]
#  [0.65867347]
#  [0.65115585]
#  [0.68248217]]
# Error [[-0.61424806]
#  [ 0.34132653]
#  [ 0.34884415]
#  [-0.68248217]]
# Aggrigation in hidden layer
# [[0.68749146 0.20032904]
#  [1.30644494 1.17459207]
#  [1.36333932 0.79502154]
#  [1.98229279 1.76928458]]
#
# Applying Activation in Hidden layer
# [[0.66540866 0.54991544]
#  [0.78691766 0.76397405]
#  [0.79630189 0.68890853]
#  [0.87892536 0.85436868]]
#
# Aggrigation in Output Layer
# [[0.43907723]
#  [0.62806341]
#  [0.59539956]
#  [0.73417595]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.60803913]
#  [0.65205022]
#  [0.64460309]
#  [0.67572099]]
# Error [[-0.60803913]
#  [ 0.34794978]
#  [ 0.35539691]
#  [-0.67572099]]
# Aggrigation in hidden layer
# [[0.68609677 0.19916269]
#  [1.30488739 1.17320965]
#  [1.36177979 0.79380495]
#  [1.98057041 1.76785191]]
#
# Applying Activation in Hidden layer
# [[0.66509807 0.54962674]
#  [0.78665637 0.76372468]
#  [0.79604881 0.68864774]
#  [0.87874196 0.85419033]]
#
# Aggrigation in Output Layer
# [[0.41390559]
#  [0.59981067]
#  [0.5677268 ]
#  [0.70428061]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.602024  ]
#  [0.64561299]
#  [0.63823848]
#  [0.66913615]]
# Error [[-0.602024  ]
#  [ 0.35438701]
#  [ 0.36176152]
#  [-0.66913615]]
# Aggrigation in hidden layer
# [[0.68477651 0.19806687]
#  [1.30342856 1.17192019]
#  [1.36031798 0.79268167]
#  [1.97897003 1.76653499]]
#
# Applying Activation in Hidden layer
# [[0.66480393 0.54935547]
#  [0.78641144 0.76349192]
#  [0.79581137 0.68840685]
#  [0.87857132 0.85402623]]
#
# Aggrigation in Output Layer
# [[0.38968746]
#  [0.57262835]
#  [0.54110359]
#  [0.67551519]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.59620746]
#  [0.63936943]
#  [0.6320691 ]
#  [0.662737  ]]
# Error [[-0.59620746]
#  [ 0.36063057]
#  [ 0.3679309 ]
#  [-0.662737  ]]
# Aggrigation in hidden layer
# [[0.68352799 0.19703873]
#  [1.30206493 1.17072003]
#  [1.35895039 0.79164789]
#  [1.97748733 1.76532919]]
#
# Applying Activation in Hidden layer
# [[0.66452565 0.54910093]
#  [0.7861823  0.76327514]
#  [0.79558906 0.68818506]
#  [0.87841306 0.85387585]]
#
# Aggrigation in Output Layer
# [[0.36641646]
#  [0.54650975]
#  [0.51552317]
#  [0.64787312]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.59059279]
#  [0.63332545]
#  [0.62610034]
#  [0.65653101]]
# Error [[-0.59059279]
#  [ 0.36667455]
#  [ 0.37389966]
#  [-0.65653101]]
# Aggrigation in hidden layer
# [[0.68234839 0.19607533]
#  [1.3007928  1.16960538]
#  [1.35767337 0.79069972]
#  [1.97611779 1.76422977]]
#
# Applying Activation in Hidden layer
# [[0.66426263 0.54886239]
#  [0.78596838 0.76307368]
#  [0.7953813  0.68798155]
#  [0.87826671 0.85373862]]
#
# Aggrigation in Output Layer
# [[0.34408227]
#  [0.52144364]
#  [0.49097439]
#  [0.62134302]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.58518181]
#  [0.62748528]
#  [0.62033595]
#  [0.65052394]]
# Error [[-0.58518181]
#  [ 0.37251472]
#  [ 0.37966405]
#  [-0.65052394]]
# Aggrigation in hidden layer
# [[0.68123483 0.1951737 ]
#  [1.29960838 1.1685724 ]
#  [1.35648317 0.78983317]
#  [1.97485673 1.76323186]]
#
# Applying Activation in Hidden layer
# [[0.66401424 0.54863912]
#  [0.78576907 0.76288687]
#  [0.79518753 0.68779551]
#  [0.87813182 0.85361397]]
#
# Aggrigation in Output Layer
# [[0.32267105]
#  [0.49741482]
#  [0.46744223]
#  [0.59590927]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.57997507]
#  [0.62185161]
#  [0.61477819]
#  [0.64471986]]
# Error [[-0.57997507]
#  [ 0.37814839]
#  [ 0.38522181]
#  [-0.64471986]]
# Aggrigation in hidden layer
# [[0.6801844  0.19433086]
#  [1.29850782 1.16761721]
#  [1.35537597 0.78904426]
#  [1.97369939 1.76233061]]
#
# Applying Activation in Hidden layer
# [[0.66377985 0.5484304 ]
#  [0.78558375 0.76271404]
#  [0.79500714 0.68762608]
#  [0.87800791 0.85350131]]
#
# Aggrigation in Output Layer
# [[0.3021659 ]
#  [0.47440461]
#  [0.44490824]
#  [0.5715525 ]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.5749719 ]
#  [0.61642574]
#  [0.60942794]
#  [0.63912133]]
# Error [[-0.5749719 ]
#  [ 0.38357426]
#  [ 0.39057206]
#  [-0.63912133]]
# Aggrigation in hidden layer
# [[0.67919416 0.19354385]
#  [1.29748724 1.16673593]
#  [1.35434793 0.78832905]
#  [1.972641   1.76152114]]
#
# Applying Activation in Hidden layer
# [[0.66355882 0.54823548]
#  [0.78541179 0.76255451]
#  [0.79483955 0.68747243]
#  [0.8778945  0.85340007]]
#
# Aggrigation in Output Layer
# [[0.28254728]
#  [0.45239132]
#  [0.42335108]
#  [0.54825013]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.57017061]
#  [0.61120764]
#  [0.60428485]
#  [0.63372951]]
# Error [[-0.57017061]
#  [ 0.38879236]
#  [ 0.39571515]
#  [-0.63372951]]
# Aggrigation in hidden layer
# [[0.6782612  0.19280975]
#  [1.29654277 1.16592476]
#  [1.35339522 0.78768364]
#  [1.97167678 1.76079866]]
#
# Applying Activation in Hidden layer
# [[0.66335051 0.54805366]
#  [0.78525256 0.76240761]
#  [0.79468415 0.68733375]
#  [0.8777911  0.85330966]]
#
# Aggrigation in Output Layer
# [[0.26379349]
#  [0.43135078]
#  [0.40274696]
#  [0.5259769 ]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.56556859]
#  [0.60619618]
#  [0.59934747]
#  [0.6285443 ]]
# Error [[-0.56556859]
#  [ 0.39380382]
#  [ 0.40065253]
#  [-0.6285443 ]]
# Aggrigation in hidden layer
# [[0.67738266 0.19212571]
#  [1.2956706  1.16517996]
#  [1.35251408 0.78710421]
#  [1.97080202 1.76015847]]
#
# Applying Activation in Hidden layer
# [[0.66315428 0.54788422]
#  [0.78510545 0.76227267]
#  [0.79454035 0.68720921]
#  [0.87769723 0.85322951]]
#
# Aggrigation in Output Layer
# [[0.24588099]
#  [0.41125676]
#  [0.3830701 ]
#  [0.50470536]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.56116241]
#  [0.60138919]
#  [0.59461336]
#  [0.62356447]]
# Error [[-0.56116241]
#  [ 0.39861081]
#  [ 0.40538664]
#  [-0.62356447]]
# Aggrigation in hidden layer
# [[0.67655572 0.19148895]
#  [1.29486699 1.16449787]
#  [1.35170081 0.78658707]
#  [1.97001209 1.75959598]]
#
# Applying Activation in Hidden layer
# [[0.66296954 0.54772649]
#  [0.78496984 0.76214904]
#  [0.79440755 0.68709804]
#  [0.87761241 0.85315905]]
#
# Aggrigation in Output Layer
# [[0.22878484]
#  [0.3920814 ]
#  [0.36429313]
#  [0.48440625]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.55694803]
#  [0.59678365]
#  [0.59007928]
#  [0.6187878 ]]
# Error [[-0.55694803]
#  [ 0.40321635]
#  [ 0.40992072]
#  [-0.6187878 ]]
# Aggrigation in hidden layer
# [[0.67577764 0.19089681]
#  [1.29412831 1.16387496]
#  [1.35095181 0.78612863]
#  [1.96930249 1.75910677]]
#
# Applying Activation in Hidden layer
# [[0.66279566 0.5475798 ]
#  [0.78484513 0.7620361 ]
#  [0.79428519 0.68699947]
#  [0.87753617 0.85309775]]
#
# Aggrigation in Output Layer
# [[0.21247902]
#  [0.37379558]
#  [0.34638747]
#  [0.46504899]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.5529208 ]
#  [0.59237581]
#  [0.58574128]
#  [0.61421125]]
# Error [[-0.5529208 ]
#  [ 0.40762419]
#  [ 0.41425872]
#  [-0.61421125]]
# Aggrigation in hidden layer
# [[0.67504577 0.1903467 ]
#  [1.29345101 1.16330783]
#  [1.35026358 0.78572545]
#  [1.96866883 1.75868658]]
#
# Applying Activation in Hidden layer
# [[0.66263207 0.54744351]
#  [0.78473074 0.76193324]
#  [0.79417272 0.68691276]
#  [0.87746806 0.85304509]]
#
# Aggrigation in Output Layer
# [[0.19693673]
#  [0.35636931]
#  [0.32932367]
#  [0.44660202]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.54907567]
#  [0.58816126]
#  [0.58159481]
#  [0.60983103]]
# Error [[-0.54907567]
#  [ 0.41183874]
#  [ 0.41840519]
#  [-0.60983103]]
# Aggrigation in hidden layer
# [[0.67435756 0.18983614]
#  [1.29283171 1.16279321]
#  [1.34963276 0.78537423]
#  [1.96810691 1.7583313 ]]
#
# Applying Activation in Hidden layer
# [[0.6624782  0.54731702]
#  [0.7846261  0.76183989]
#  [0.79406958 0.68683723]
#  [0.87740763 0.85300054]]
#
# Aggrigation in Output Layer
# [[0.18213067]
#  [0.339772  ]
#  [0.31307174]
#  [0.42903314]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.54540722]
#  [0.58413514]
#  [0.57763486]
#  [0.60564277]]
# Error [[-0.54540722]
#  [ 0.41586486]
#  [ 0.42236514]
#  [-0.60564277]]
# Aggrigation in hidden layer
# [[0.67371056 0.18936279]
#  [1.29226711 1.162328  ]
#  [1.34905611 0.78507184]
#  [1.96761266 1.75803704]]
#
# Applying Activation in Hidden layer
# [[0.66233352 0.54719974]
#  [0.78453067 0.76175547]
#  [0.79397527 0.68677218]
#  [0.87735446 0.85296364]]
#
# Aggrigation in Output Layer
# [[0.16803329]
#  [0.32397276]
#  [0.29760138]
#  [0.41230978]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.54190976]
#  [0.58029214]
#  [0.57385605]
#  [0.60164159]]
# Error [[-0.54190976]
#  [ 0.41970786]
#  [ 0.42614395]
#  [-0.60164159]]
# Aggrigation in hidden layer
# [[0.67310241 0.18892441]
#  [1.29175409 1.16190921]
#  [1.34853053 0.78481528]
#  [1.96718221 1.75780008]]
#
# Applying Activation in Hidden layer
# [[0.66219749 0.54709112]
#  [0.78444394 0.76167946]
#  [0.79388928 0.68671699]
#  [0.87730813 0.85293392]]
#
# Aggrigation in Output Layer
# [[0.15461699]
#  [0.30894064]
#  [0.28288223]
#  [0.39639929]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.53857742]
#  [0.57662666]
#  [0.5702527 ]
#  [0.59782224]]
# Error [[-0.53857742]
#  [ 0.42337334]
#  [ 0.4297473 ]
#  [-0.59782224]]
# Aggrigation in hidden layer
# [[0.67253089 0.18851885]
#  [1.29128967 1.16153403]
#  [1.34805307 0.78460173]
#  [1.96681185 1.7576169 ]]
#
# Applying Activation in Hidden layer
# [[0.66206964 0.54699063]
#  [0.7843654  0.76161134]
#  [0.79381115 0.68667104]
#  [0.87726826 0.85291094]]
#
# Aggrigation in Output Layer
# [[0.14185432]
#  [0.29464481]
#  [0.26888408]
#  [0.38126916]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.53540423]
#  [0.57313288]
#  [0.56681893]
#  [0.59417917]]
# Error [[-0.53540423]
#  [ 0.42686712]
#  [ 0.43318107]
#  [-0.59417917]]
# Aggrigation in hidden layer
# [[0.67199384 0.18814411]
#  [1.290871   1.16119978]
#  [1.34762091 0.7844285 ]
#  [1.96649807 1.75748417]]
#
# Applying Activation in Hidden layer
# [[0.66194947 0.54689777]
#  [0.78429458 0.76155065]
#  [0.7937404  0.68663377]
#  [0.87723447 0.85289429]]
#
# Aggrigation in Output Layer
# [[0.12971813]
#  [0.28105479]
#  [0.25557704]
#  [0.36688717]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.53238413]
#  [0.5698048 ]
#  [0.56354872]
#  [0.5907066 ]]
# Error [[-0.53238413]
#  [ 0.4301952 ]
#  [ 0.43645128]
#  [-0.5907066 ]]
# Aggrigation in hidden layer
# [[0.67148926 0.18779828]
#  [1.29049538 1.16090395]
#  [1.34723139 0.78429307]
#  [1.96623751 1.75739873]]
#
# Applying Activation in Hidden layer
# [[0.66183655 0.54681207]
#  [0.78423102 0.76149693]
#  [0.79367663 0.68660463]
#  [0.87720641 0.85288357]]
#
# Aggrigation in Output Layer
# [[0.11818167]
#  [0.26814055]
#  [0.24293169]
#  [0.35322161]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.52951108]
#  [0.56663636]
#  [0.56043599]
#  [0.58739859]]
# Error [[-0.52951108]
#  [ 0.43336364]
#  [ 0.43956401]
#  [-0.58739859]]
# Aggrigation in hidden layer
# [[0.67101522 0.18747958]
#  [1.29016025 1.16064414]
#  [1.34688198 0.78419306]
#  [1.96602701 1.75735762]]
#
# Applying Activation in Hidden layer
# [[0.66173045 0.54673309]
#  [0.78417431 0.76144974]
#  [0.7936194  0.68658311]
#  [0.87718373 0.85287841]]
#
# Aggrigation in Output Layer
# [[0.10721875]
#  [0.25587264]
#  [0.23091916]
#  [0.34024135]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.52677904]
#  [0.56362143]
#  [0.55747462]
#  [0.58424915]]
# Error [[-0.52677904]
#  [ 0.43637857]
#  [ 0.44252538]
#  [-0.58424915]]
# Aggrigation in hidden layer
# [[0.67056992 0.18718632]
#  [1.2898632  1.16041814]
#  [1.34657028 0.78412624]
#  [1.96586357 1.75735806]]
#
# Applying Activation in Hidden layer
# [[0.66163076 0.54666042]
#  [0.78412403 0.76140868]
#  [0.79356835 0.68656873]
#  [0.87716613 0.85287847]]
#
# Aggrigation in Output Layer
# [[0.0968038 ]
#  [0.24422231]
#  [0.2195113 ]
#  [0.32791599]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.52418207]
#  [0.56075391]
#  [0.55465852]
#  [0.58125222]]
# Error [[-0.52418207]
#  [ 0.43924609]
#  [ 0.44534148]
#  [-0.58125222]]
# Aggrigation in hidden layer
# [[0.67015163 0.1869169 ]
#  [1.28960196 1.16022382]
#  [1.34629405 0.78409052]
#  [1.96574437 1.75739743]]
#
# Applying Activation in Hidden layer
# [[0.66153711 0.54659365]
#  [0.78407981 0.76137338]
#  [0.79352309 0.68656104]
#  [0.87715328 0.85288341]]
#
# Aggrigation in Output Layer
# [[0.08691191]
#  [0.23316157]
#  [0.20868068]
#  [0.31621593]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.52171431]
#  [0.55802774]
#  [0.55198167]
#  [0.57840177]]
# Error [[-0.52171431]
#  [ 0.44197226]
#  [ 0.44801833]
#  [-0.57840177]]
# Aggrigation in hidden layer
# [[0.66975875 0.18666984]
#  [1.28937436 1.16005921]
#  [1.34605115 0.78408391]
#  [1.96566675 1.75747328]]
#
# Applying Activation in Hidden layer
# [[0.66144914 0.54653242]
#  [0.78404127 0.76134347]
#  [0.79348329 0.68655962]
#  [0.87714492 0.85289292]]
#
# Aggrigation in Output Layer
# [[0.07751893]
#  [0.22266325]
#  [0.19840069]
#  [0.30511242]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.51937003]
#  [0.55543696]
#  [0.54943811]
#  [0.57569181]]
# Error [[-0.51937003]
#  [ 0.44456304]
#  [ 0.45056189]
#  [-0.57569181]]
# Aggrigation in hidden layer
# [[0.66938975 0.18644375]
#  [1.28917838 1.15992246]
#  [1.34583958 0.78410459]
#  [1.96562821 1.7575833 ]]
#
# Applying Activation in Hidden layer
# [[0.6613665  0.54647638]
#  [0.78400809 0.76131862]
#  [0.79344862 0.68656407]
#  [0.87714076 0.85290673]]
#
# Aggrigation in Output Layer
# [[0.0686015 ]
#  [0.21270107]
#  [0.18864557]
#  [0.29457764]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.51714365]
#  [0.55297569]
#  [0.54702203]
#  [0.57311644]]
# Error [[-0.51714365]
#  [ 0.44702431]
#  [ 0.45297797]
#  [-0.57311644]]
# Aggrigation in hidden layer
# [[0.66904321 0.18623731]
#  [1.28901212 1.15981183]
#  [1.34565745 0.78415083]
#  [1.96562637 1.75772535]]
#
# Applying Activation in Hidden layer
# [[0.66128888 0.54642522]
#  [0.78397993 0.76129852]
#  [0.79341877 0.68657402]
#  [0.87714057 0.85292455]]
#
# Aggrigation in Output Layer
# [[0.06013704]
#  [0.20324963]
#  [0.17939047]
#  [0.28458472]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.51502973]
#  [0.5506382 ]
#  [0.54472773]
#  [0.57066987]]
# Error [[-0.51502973]
#  [ 0.4493618 ]
#  [ 0.45527227]
#  [-0.57066987]]
# Aggrigation in hidden layer
# [[0.66871777 0.1860493 ]
#  [1.28887379 1.1597257 ]
#  [1.345503   0.78422102]
#  [1.96565903 1.75789742]]
#
# Applying Activation in Hidden layer
# [[0.66121599 0.54637862]
#  [0.78395651 0.76128287]
#  [0.79339345 0.68658913]
#  [0.87714409 0.85294613]]
#
# Aggrigation in Output Layer
# [[0.05210382]
#  [0.19428447]
#  [0.17061142]
#  [0.27510773]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.51302301]
#  [0.54841891]
#  [0.54254969]
#  [0.56834641]]
# Error [[-0.51302301]
#  [ 0.45158109]
#  [ 0.45745031]
#  [-0.56834641]]
# Aggrigation in hidden layer
# [[0.66841217 0.18587858]
#  [1.28876171 1.15966254]
#  [1.34537456 0.78431366]
#  [1.9657241  1.75809762]]
#
# Applying Activation in Hidden layer
# [[0.66114753 0.54633631]
#  [0.78393752 0.76127139]
#  [0.7933724  0.68660906]
#  [0.8771511  0.85297124]]
#
# Aggrigation in Output Layer
# [[0.04448092]
#  [0.18578204]
#  [0.16228536]
#  [0.26612176]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.5111184 ]
#  [0.54631238]
#  [0.54048253]
#  [0.56614056]]
# Error [[-0.5111184 ]
#  [ 0.45368762]
#  [ 0.45951747]
#  [-0.56614056]]
# Aggrigation in hidden layer
# [[0.66812522 0.18572406]
#  [1.28867429 1.15962093]
#  [1.34527057 0.78442733]
#  [1.96581965 1.7583242 ]]
#
# Applying Activation in Hidden layer
# [[0.66108324 0.54629801]
#  [0.78392272 0.76126383]
#  [0.79335535 0.68663352]
#  [0.87716139 0.85299965]]
#
# Aggrigation in Output Layer
# [[0.03724827]
#  [0.17771975]
#  [0.15439017]
#  [0.25760286]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.50931099]
#  [0.54431336]
#  [0.53852106]
#  [0.56404693]]
# Error [[-0.50931099]
#  [ 0.45568664]
#  [ 0.46147894]
#  [-0.56404693]]
# Aggrigation in hidden layer
# [[0.6678558  0.18558475]
#  [1.28861007 1.15959955]
#  [1.34518956 0.78456073]
#  [1.96594383 1.75857552]]
#
# Applying Activation in Hidden layer
# [[0.66102287 0.54626348]
#  [0.78391184 0.76125994]
#  [0.79334207 0.68666222]
#  [0.87717477 0.85303116]]
#
# Aggrigation in Output Layer
# [[0.03038661]
#  [0.17007591]
#  [0.14690462]
#  [0.24952806]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.50759607]
#  [0.54241678]
#  [0.53666025]
#  [0.56206034]]
# Error [[-0.50759607]
#  [ 0.45758322]
#  [ 0.46333975]
#  [-0.56206034]]
# Aggrigation in hidden layer
# [[0.66760288 0.18545972]
#  [1.28856764 1.15959714]
#  [1.34513016 0.78471263]
#  [1.96609492 1.75885005]]
#
# Applying Activation in Hidden layer
# [[0.6609662  0.54623249]
#  [0.78390465 0.76125951]
#  [0.79333233 0.6866949 ]
#  [0.87719105 0.85306558]]
#
# Aggrigation in Output Layer
# [[0.0238775 ]
#  [0.16282977]
#  [0.13980838]
#  [0.24187536]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.50596909]
#  [0.54061774]
#  [0.53489527]
#  [0.56017575]]
# Error [[-0.50596909]
#  [ 0.45938226]
#  [ 0.46510473]
#  [-0.56017575]]
# Aggrigation in hidden layer
# [[0.66736545 0.18534807]
#  [1.28854571 1.15961254]
#  [1.34509107 0.78488188]
#  [1.96627133 1.75914636]]
#
# Applying Activation in Hidden layer
# [[0.66091299 0.54620482]
#  [0.78390093 0.7612623 ]
#  [0.79332592 0.68673132]
#  [0.87721005 0.85310272]]
#
# Aggrigation in Output Layer
# [[0.01770332]
#  [0.15596147]
#  [0.13308201]
#  [0.23462371]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.50442572]
#  [0.53891153]
#  [0.53322148]
#  [0.55838833]]
# Error [[-0.50442572]
#  [ 0.46108847]
#  [ 0.46677852]
#  [-0.55838833]]
# Aggrigation in hidden layer
# [[0.66714261 0.18524899]
#  [1.28854305 1.15964468]
#  [1.34507109 0.78506743]
#  [1.96647154 1.75946311]]
#
# Applying Activation in Hidden layer
# [[0.66086305 0.54618026]
#  [0.78390048 0.76126815]
#  [0.79332264 0.68677123]
#  [0.87723162 0.85314241]]
#
# Aggrigation in Output Layer
# [[0.01184722]
#  [0.14945202]
#  [0.12670692]
#  [0.227753  ]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.50296177]
#  [0.53729362]
#  [0.53163442]
#  [0.5566934 ]]
# Error [[-0.50296177]
#  [ 0.46270638]
#  [ 0.46836558]
#  [-0.5566934 ]]
# Aggrigation in hidden layer
# [[0.66693348 0.18516172]
#  [1.28855852 1.15969253]
#  [1.34506909 0.78526826]
#  [1.96669413 1.75979907]]
#
# Applying Activation in Hidden layer
# [[0.66081617 0.54615863]
#  [0.7839031  0.76127684]
#  [0.79332232 0.68681443]
#  [0.87725559 0.85318449]]
#
# Aggrigation in Output Layer
# [[0.00629311]
#  [0.14328331]
#  [0.12066538]
#  [0.22124401]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.50157327]
#  [0.53575967]
#  [0.5301298 ]
#  [0.55508648]]
# Error [[-0.50157327]
#  [ 0.46424033]
#  [ 0.4698702 ]
#  [-0.55508648]]
# Aggrigation in hidden layer
# [[0.66673726 0.18508553]
#  [1.28859105 1.15975514]
#  [1.34508399 0.78548346]
#  [1.96693779 1.76015306]]
#
# Applying Activation in Hidden layer
# [[0.66077219 0.54613974]
#  [0.78390861 0.76128822]
#  [0.79332476 0.68686072]
#  [0.87728182 0.85322883]]
#
# Aggrigation in Output Layer
# [[0.00102564]
#  [0.13743805]
#  [0.11494046]
#  [0.21507842]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.50025641]
#  [0.53430553]
#  [0.52870352]
#  [0.55356328]]
# Error [[-0.50025641]
#  [ 0.46569447]
#  [ 0.47129648]
#  [-0.55356328]]
# Aggrigation in hidden layer
# [[0.66655317 0.18501977]
#  [1.28863963 1.15983163]
#  [1.34511481 0.78571215]
#  [1.96720127 1.76052402]]
#
# Applying Activation in Hidden layer
# [[0.66073093 0.54612344]
#  [0.78391684 0.76130212]
#  [0.79332981 0.68690991]
#  [0.87731018 0.85327528]]
#
# Aggrigation in Output Layer
# [[-0.0039698 ]
#  [ 0.13189977]
#  [ 0.10951604]
#  [ 0.20923874]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.49900755]
#  [0.53292722]
#  [0.52735168]
#  [0.55211967]]
# Error [[-0.49900755]
#  [ 0.46707278]
#  [ 0.47264832]
#  [-0.55211967]]
# Aggrigation in hidden layer
# [[0.66638051 0.18496379]
#  [1.28870331 1.15992117]
#  [1.34516061 0.78595353]
#  [1.96748341 1.76091091]]
#
# Applying Activation in Hidden layer
# [[0.66069222 0.54610956]
#  [0.78392763 0.76131839]
#  [0.79333732 0.68696181]
#  [0.87734055 0.85332371]]
#
# Aggrigation in Output Layer
# [[-0.00870715]
#  [ 0.12665276]
#  [ 0.10437674]
#  [ 0.20370835]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.49782323]
#  [0.53162093]
#  [0.52607052]
#  [0.5507517 ]]
# Error [[-0.49782323]
#  [ 0.46837907]
#  [ 0.47392948]
#  [-0.5507517 ]]
# Aggrigation in hidden layer
# [[0.66621861 0.18491701]
#  [1.28878121 1.16002298]
#  [1.34522052 0.78620683]
#  [1.96778312 1.7613128 ]]
#
# Applying Activation in Hidden layer
# [[0.66065593 0.54609797]
#  [0.78394082 0.76133689]
#  [0.79334714 0.68701628]
#  [0.8773728  0.853374  ]]
#
# Aggrigation in Output Layer
# [[-0.01319967]
#  [ 0.12168208]
#  [ 0.09950793]
#  [ 0.19847137]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.49670013]
#  [0.53038304]
#  [0.52485648]
#  [0.54945561]]
# Error [[-0.49670013]
#  [ 0.46961696]
#  [ 0.47514352]
#  [-0.54945561]]
# Aggrigation in hidden layer
# [[0.66606683 0.18487889]
#  [1.2888725  1.16013635]
#  [1.3452937  0.78647135]
#  [1.96809937 1.76172881]]
#
# Applying Activation in Hidden layer
# [[0.6606219  0.54608852]
#  [0.78395629 0.76135749]
#  [0.79335914 0.68707316]
#  [0.87740682 0.85342605]]
#
# Aggrigation in Output Layer
# [[-0.01745997]
#  [ 0.11697351]
#  [ 0.0948957 ]
#  [ 0.19351273]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.49563512]
#  [0.52921008]
#  [0.52370614]
#  [0.54822778]]
# Error [[-0.49563512]
#  [ 0.47078992]
#  [ 0.47629386]
#  [-0.54822778]]
# Aggrigation in hidden layer
# [[0.66592458 0.1848489 ]
#  [1.2889764  1.16026058]
#  [1.3453794  0.78674642]
#  [1.96843122 1.7621581 ]]
#
# Applying Activation in Hidden layer
# [[0.66059001 0.54608109]
#  [0.78397388 0.76138006]
#  [0.79337319 0.6871323 ]
#  [0.87744251 0.85347974]]
#
# Aggrigation in Output Layer
# [[-0.02150006]
#  [ 0.11251352]
#  [ 0.09052681]
#  [ 0.18881808]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.49462519]
#  [0.52809874]
#  [0.52261626]
#  [0.54706477]]
# Error [[-0.49462519]
#  [ 0.47190126]
#  [ 0.47738374]
#  [-0.54706477]]
# Aggrigation in hidden layer
# [[0.66579132 0.18482658]
#  [1.28909219 1.16039506]
#  [1.34547688 0.78703144]
#  [1.96877775 1.76259992]]
#
# Applying Activation in Hidden layer
# [[0.66056013 0.54607555]
#  [0.78399349 0.76140449]
#  [0.79338917 0.68719357]
#  [0.87747977 0.85353498]]
#
# Aggrigation in Output Layer
# [[-0.02533134]
#  [ 0.10828925]
#  [ 0.08638866]
#  [ 0.18437376]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.4936675 ]
#  [0.52704589]
#  [0.52158374]
#  [0.54596331]]
# Error [[-0.4936675 ]
#  [ 0.47295411]
#  [ 0.47841626]
#  [-0.54596331]]
# Aggrigation in hidden layer
# [[0.66566651 0.18481147]
#  [1.28921918 1.16053918]
#  [1.34558547 0.78732582]
#  [1.96913814 1.76305353]]
#
# Applying Activation in Hidden layer
# [[0.66053214 0.54607181]
#  [0.784015   0.76143067]
#  [0.79340697 0.68725684]
#  [0.87751851 0.85359168]]
#
# Aggrigation in Output Layer
# [[-0.02896465]
#  [ 0.10428849]
#  [ 0.0824693 ]
#  [ 0.18016683]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.49275934]
#  [0.52604852]
#  [0.52060565]
#  [0.54492026]]
# Error [[-0.49275934]
#  [ 0.47395148]
#  [ 0.47939435]
#  [-0.54492026]]
# Aggrigation in hidden layer
# [[0.66554967 0.18480314]
#  [1.28935672 1.16069239]
#  [1.34570454 0.78762902]
#  [1.96951158 1.76351827]]
#
# Applying Activation in Hidden layer
# [[0.66050594 0.54606974]
#  [0.78403829 0.7614585 ]
#  [0.79342649 0.68732201]
#  [0.87755864 0.85364975]]
#
# Aggrigation in Output Layer
# [[-0.03241029]
#  [ 0.10049962]
#  [ 0.07875735]
#  [ 0.17618495]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.49189814]
#  [0.52510378]
#  [0.51967917]
#  [0.54393265]]
# Error [[-0.49189814]
#  [ 0.47489622]
#  [ 0.48032083]
#  [-0.54393265]]
# Aggrigation in hidden layer
# [[0.66544034 0.18480121]
#  [1.28950421 1.16085417]
#  [1.34583348 0.78794054]
#  [1.96989735 1.7639935 ]]
#
# Applying Activation in Hidden layer
# [[0.66048143 0.54606927]
#  [0.78406326 0.76148789]
#  [0.79344762 0.68738895]
#  [0.87760009 0.85370911]]
#
# Aggrigation in Output Layer
# [[-0.03567805]
#  [ 0.09691162]
#  [ 0.07524203]
#  [ 0.17241643]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.49108143]
#  [0.52420896]
#  [0.51880164]
#  [0.54299764]]
# Error [[-0.49108143]
#  [ 0.47579104]
#  [ 0.48119836]
#  [-0.54299764]]
# Aggrigation in hidden layer
# [[0.66533809 0.1848053 ]
#  [1.28966109 1.16102404]
#  [1.34597173 0.7882599 ]
#  [1.97029473 1.76447864]]
#
# Applying Activation in Hidden layer
# [[0.6604585  0.54607028]
#  [0.78408982 0.76151874]
#  [0.79347028 0.68745758]
#  [0.87764277 0.85376969]]
#
# Aggrigation in Output Layer
# [[-0.03877719]
#  [ 0.09351402]
#  [ 0.07191309]
#  [ 0.16885014]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.49030692]
#  [0.52336148]
#  [0.51797053]
#  [0.54211253]]
# Error [[-0.49030692]
#  [ 0.47663852]
#  [ 0.48202947]
#  [-0.54211253]]
# Aggrigation in hidden layer
# [[0.66524251 0.18481506]
#  [1.28982682 1.16120152]
#  [1.34611877 0.78858667]
#  [1.97070308 1.76497313]]
#
# Applying Activation in Hidden layer
# [[0.66043706 0.5460727 ]
#  [0.78411788 0.76155097]
#  [0.79349437 0.68752778]
#  [0.87768661 0.85383142]]
#
# Aggrigation in Output Layer
# [[-0.04171655]
#  [ 0.09029687]
#  [ 0.06876081]
#  [ 0.16547556]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.48957238]
#  [0.52255889]
#  [0.51718343]
#  [0.54127475]]
# Error [[-0.48957238]
#  [ 0.47744111]
#  [ 0.48281657]
#  [-0.54127475]]
# Aggrigation in hidden layer
# [[0.66515322 0.18483017]
#  [1.29000091 1.16138621]
#  [1.3462741  0.78892042]
#  [1.97112179 1.76547646]]
#
# Applying Activation in Hidden layer
# [[0.66041704 0.54607644]
#  [0.78414734 0.76158451]
#  [0.79351982 0.68759948]
#  [0.87773155 0.85389422]]
#
# Aggrigation in Output Layer
# [[-0.04450447]
#  [ 0.08725075]
#  [ 0.06577594]
#  [ 0.16228265]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.48887572]
#  [0.52179886]
#  [0.51643806]
#  [0.54048186]]
# Error [[-0.48887572]
#  [ 0.47820114]
#  [ 0.48356194]
#  [-0.54048186]]
# Aggrigation in hidden layer
# [[0.66506986 0.18485032]
#  [1.29018288 1.16157769]
#  [1.34643726 0.78926077]
#  [1.97155028 1.76598814]]
#
# Applying Activation in Hidden layer
# [[0.66039834 0.54608144]
#  [0.78417814 0.76161927]
#  [0.79354655 0.68767258]
#  [0.87777753 0.85395805]]
#
# Aggrigation in Output Layer
# [[-0.0471489 ]
#  [ 0.08436671]
#  [ 0.06294973]
#  [ 0.15926194]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.48821496]
#  [0.52107918]
#  [0.51573224]
#  [0.53973154]]
# Error [[-0.48821496]
#  [ 0.47892082]
#  [ 0.48426776]
#  [-0.53973154]]
# Aggrigation in hidden layer
# [[0.6649921  0.18487524]
#  [1.29037229 1.1617756 ]
#  [1.34660781 0.78960735]
#  [1.971988   1.76650772]]
#
# Applying Activation in Hidden layer
# [[0.6603809  0.54608762]
#  [0.7842102  0.7616552 ]
#  [0.79357449 0.68774702]
#  [0.87782448 0.85402283]]
#
# Aggrigation in Output Layer
# [[-0.04965736]
#  [ 0.08163626]
#  [ 0.06027388]
#  [ 0.15640439]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.48758821]
#  [0.52039774]
#  [0.51506391]
#  [0.53902158]]
# Error [[-0.48758821]
#  [ 0.47960226]
#  [ 0.48493609]
#  [-0.53902158]]
# Aggrigation in hidden layer
# [[0.66491961 0.18490463]
#  [1.29056874 1.16197957]
#  [1.34678533 0.78995983]
#  [1.97243446 1.76703477]]
#
# Applying Activation in Hidden layer
# [[0.66036464 0.5460949 ]
#  [0.78424344 0.76169223]
#  [0.79360357 0.68782271]
#  [0.87787236 0.85408853]]
#
# Aggrigation in Output Layer
# [[-0.05203699]
#  [ 0.07905134]
#  [ 0.0577405 ]
#  [ 0.15370147]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.48699369]
#  [0.51975255]
#  [0.51443111]
#  [0.5383499 ]]
# Error [[-0.48699369]
#  [ 0.48024745]
#  [ 0.48556889]
#  [-0.5383499 ]]
# Aggrigation in hidden layer
# [[0.6648521  0.18493827]
#  [1.29077182 1.16218927]
#  [1.34696944 0.79031789]
#  [1.97288916 1.76756889]]
#
# Applying Activation in Hidden layer
# [[0.6603495  0.54610324]
#  [0.7842778  0.76173029]
#  [0.79363373 0.68789958]
#  [0.8779211  0.85415508]]
#
# Aggrigation in Output Layer
# [[-0.05429456]
#  [ 0.07660432]
#  [ 0.05534211]
#  [ 0.15114507]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.48642969]
#  [0.51914172]
#  [0.513832  ]
#  [0.5377145 ]]
# Error [[-0.48642969]
#  [ 0.48085828]
#  [ 0.486168  ]
#  [-0.5377145 ]]
# Aggrigation in hidden layer
# [[0.66478929 0.1849759 ]
#  [1.29098118 1.1624044 ]
#  [1.34715978 0.79068121]
#  [1.97335167 1.76810972]]
#
# Applying Activation in Hidden layer
# [[0.66033541 0.54611257]
#  [0.78431322 0.76176933]
#  [0.7936649  0.68797758]
#  [0.87797066 0.85422244]]
#
# Aggrigation in Output Layer
# [[-0.0564365 ]
#  [ 0.07428796]
#  [ 0.05307163]
#  [ 0.14872749]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.48589462]
#  [0.51856345]
#  [0.51326479]
#  [0.53711349]]
# Error [[-0.48589462]
#  [ 0.48143655]
#  [ 0.48673521]
#  [-0.53711349]]
# Aggrigation in hidden layer
# [[0.66473091 0.1850173 ]
#  [1.29119646 1.16262467]
#  [1.34735601 0.79104953]
#  [1.97382156 1.76865689]]
#
# Applying Activation in Hidden layer
# [[0.66032232 0.54612283]
#  [0.78434963 0.7618093 ]
#  [0.79369703 0.68805664]
#  [0.87802099 0.85429056]]
#
# Aggrigation in Output Layer
# [[-0.05846888]
#  [ 0.07209539]
#  [ 0.05092233]
#  [ 0.14644145]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.48538694]
#  [0.51801605]
#  [0.51272783]
#  [0.53654508]]
# Error [[-0.48538694]
#  [ 0.48198395]
#  [ 0.48727217]
#  [-0.53654508]]
# Aggrigation in hidden layer
# [[0.66467672 0.18506227]
#  [1.29141735 1.16284979]
#  [1.3475578  0.79142257]
#  [1.97429843 1.76921009]]
#
# Applying Activation in Hidden layer
# [[0.66031016 0.54613398]
#  [0.78438699 0.76185015]
#  [0.79373007 0.6881367 ]
#  [0.87807206 0.85435941]]
#
# Aggrigation in Output Layer
# [[-0.06039747]
#  [ 0.07002011]
#  [ 0.04888786]
#  [ 0.14428004]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.48490522]
#  [0.51749788]
#  [0.51221953]
#  [0.53600757]]
# Error [[-0.48490522]
#  [ 0.48250212]
#  [ 0.48778047]
#  [-0.53600757]]
# Aggrigation in hidden layer
# [[0.66462647 0.1851106 ]
#  [1.29164353 1.1630795 ]
#  [1.34776485 0.79180009]
#  [1.97478191 1.76976899]]
#
# Applying Activation in Hidden layer
# [[0.66029889 0.54614596]
#  [0.78442524 0.76189183]
#  [0.79376397 0.68821771]
#  [0.87812381 0.85442894]]
#
# Aggrigation in Output Layer
# [[-0.06222776]
#  [ 0.06805593]
#  [ 0.04696215]
#  [ 0.1422367 ]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.48444808]
#  [0.51700742]
#  [0.51173838]
#  [0.53549934]]
# Error [[-0.48444808]
#  [ 0.48299258]
#  [ 0.48826162]
#  [-0.53549934]]
# Aggrigation in hidden layer
# [[0.66457995 0.18516212]
#  [1.29187472 1.16331358]
#  [1.34797688 0.79218186]
#  [1.97527164 1.77033332]]
#
# Applying Activation in Hidden layer
# [[0.66028846 0.54615873]
#  [0.78446434 0.76193429]
#  [0.79379868 0.68829963]
#  [0.87817621 0.85449912]]
#
# Aggrigation in Output Layer
# [[-0.06396491]
#  [ 0.06619702]
#  [ 0.0451395 ]
#  [ 0.14030522]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.48401422]
#  [0.51654321]
#  [0.51128296]
#  [0.53501888]]
# Error [[-0.48401422]
#  [ 0.48345679]
#  [ 0.48871704]
#  [-0.53501888]]
# Aggrigation in hidden layer
# [[0.66453695 0.18521664]
#  [1.29211065 1.16355178]
#  [1.34819361 0.79256764]
#  [1.9757673  1.77090279]]
#
# Applying Activation in Hidden layer
# [[0.66027881 0.54617224]
#  [0.78450422 0.76197749]
#  [0.79383415 0.68838239]
#  [0.87822923 0.85456991]]
#
# Aggrigation in Output Layer
# [[-0.06561385]
#  [ 0.06443783]
#  [ 0.04341448]
#  [ 0.13847972]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.48360242]
#  [0.51610389]
#  [0.51085191]
#  [0.53456471]]
# Error [[-0.48360242]
#  [ 0.48389611]
#  [ 0.48914809]
#  [-0.53456471]]
# Aggrigation in hidden layer
# [[0.66449728 0.185274  ]
#  [1.29235106 1.1637939 ]
#  [1.34841479 0.79295725]
#  [1.97626857 1.77147715]]
#
# Applying Activation in Hidden layer
# [[0.66026992 0.54618646]
#  [0.78454486 0.7620214 ]
#  [0.79387034 0.68846596]
#  [0.87828283 0.85464127]]
#
# Aggrigation in Output Layer
# [[-0.06717922]
#  [ 0.0627731 ]
#  [ 0.04178193]
#  [ 0.13675461]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.48321151]
#  [0.51568812]
#  [0.51044396]
#  [0.53413547]]
# Error [[-0.48321151]
#  [ 0.48431188]
#  [ 0.48955604]
#  [-0.53413547]]
# Aggrigation in hidden layer
# [[0.66446074 0.18533404]
#  [1.29259571 1.16403972]
#  [1.34864019 0.79335048]
#  [1.97677515 1.77205616]]
#
# Applying Activation in Hidden layer
# [[0.66026172 0.54620134]
#  [0.78458622 0.76206598]
#  [0.79390723 0.68855029]
#  [0.87833697 0.85471319]]
#
# Aggrigation in Output Layer
# [[-0.06866545]
#  [ 0.06119786]
#  [ 0.040237  ]
#  [ 0.13512461]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.48284038]
#  [0.51529469]
#  [0.51005789]
#  [0.53372985]]
# Error [[-0.48284038]
#  [ 0.48470531]
#  [ 0.48994211]
#  [-0.53372985]]
# Aggrigation in hidden layer
# [[0.66442717 0.18539663]
#  [1.29284438 1.16428907]
#  [1.34886957 0.79374715]
#  [1.97728678 1.77263959]]
#
# Applying Activation in Hidden layer
# [[0.66025419 0.54621685]
#  [0.78462824 0.76211119]
#  [0.79394476 0.68863535]
#  [0.87839163 0.85478562]]
#
# Aggrigation in Output Layer
# [[-0.0700767 ]
#  [ 0.05970738]
#  [ 0.03877506]
#  [ 0.1335847 ]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.48248799]
#  [0.51492241]
#  [0.50969255]
#  [0.5333466 ]]
# Error [[-0.48248799]
#  [ 0.48507759]
#  [ 0.49030745]
#  [-0.5333466 ]]
# Aggrigation in hidden layer
# [[0.6643964  0.18546162]
#  [1.29309684 1.16454176]
#  [1.34910273 0.79414709]
#  [1.97780318 1.77322723]]
#
# Applying Activation in Hidden layer
# [[0.66024729 0.54623296]
#  [0.7846709  0.762157  ]
#  [0.7939829  0.6887211 ]
#  [0.87844679 0.85485855]]
#
# Aggrigation in Output Layer
# [[-0.07141696]
#  [ 0.0582972 ]
#  [ 0.03739173]
#  [ 0.13213015]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.48215335]
#  [0.51457017]
#  [0.50934684]
#  [0.53298456]]
# Error [[-0.48215335]
#  [ 0.48542983]
#  [ 0.49065316]
#  [-0.53298456]]
# Aggrigation in hidden layer
# [[0.66436827 0.18552889]
#  [1.29335291 1.16479762]
#  [1.34933948 0.79455014]
#  [1.97832412 1.77381887]]
#
# Applying Activation in Hidden layer
# [[0.66024098 0.54624964]
#  [0.78471416 0.76220337]
#  [0.79402162 0.6888075 ]
#  [0.8785024  0.85493194]]
#
# Aggrigation in Output Layer
# [[-0.07268996]
#  [ 0.05696308]
#  [ 0.03608287]
#  [ 0.13075644]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.48183551]
#  [0.51423692]
#  [0.50901974]
#  [0.53264261]]
# Error [[-0.48183551]
#  [ 0.48576308]
#  [ 0.49098026]
#  [-0.53264261]]
# Aggrigation in hidden layer
# [[0.66434264 0.18559831]
#  [1.29361239 1.16505649]
#  [1.3495796  0.79495614]
#  [1.97884936 1.77441433]]
#
# Applying Activation in Hidden layer
# [[0.66023523 0.54626684]
#  [0.784758   0.76225029]
#  [0.79406089 0.68889452]
#  [0.87855845 0.85500578]]
#
# Aggrigation in Output Layer
# [[-0.07389926]
#  [ 0.05570101]
#  [ 0.03484455]
#  [ 0.12945931]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.48153359]
#  [0.51392165]
#  [0.50871026]
#  [0.5323197 ]]
# Error [[-0.48153359]
#  [ 0.48607835]
#  [ 0.49128974]
#  [-0.5323197 ]]
# Aggrigation in hidden layer
# [[0.66431937 0.18566976]
#  [1.2938751  1.16531823]
#  [1.34982295 0.79536495]
#  [1.97937868 1.77501343]]
#
# Applying Activation in Hidden layer
# [[0.66023001 0.54628455]
#  [0.78480237 0.76229772]
#  [0.79410068 0.68898213]
#  [0.87861491 0.85508003]]
#
# Aggrigation in Output Layer
# [[-0.07504824]
#  [ 0.05450718]
#  [ 0.03367304]
#  [ 0.12823473]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.48124674]
#  [0.51362342]
#  [0.50841747]
#  [0.53201482]]
# Error [[-0.48124674]
#  [ 0.48637658]
#  [ 0.49158253]
#  [-0.53201482]]
# Aggrigation in hidden layer
# [[0.66429833 0.18574314]
#  [1.29414087 1.1655827 ]
#  [1.35006933 0.79577644]
#  [1.97991188 1.775616  ]]
#
# Applying Activation in Hidden layer
# [[0.66022529 0.54630274]
#  [0.78484725 0.76234564]
#  [0.79414096 0.6890703 ]
#  [0.87867177 0.85515469]]
#
# Aggrigation in Output Layer
# [[-0.07614009]
#  [ 0.05337799]
#  [ 0.03256483]
#  [ 0.12707887]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.48097417]
#  [0.51334133]
#  [0.50814049]
#  [0.53172703]]
# Error [[-0.48097417]
#  [ 0.48665867]
#  [ 0.49185951]
#  [-0.53172703]]
# Aggrigation in hidden layer
# [[0.66427939 0.18581835]
#  [1.29440954 1.16584975]
#  [1.3503186  0.79619048]
#  [1.98044875 1.77622188]]
#
# Applying Activation in Hidden layer
# [[0.66022104 0.54632138]
#  [0.78489261 0.76239402]
#  [0.79418171 0.689159  ]
#  [0.87872899 0.85522972]]
#
# Aggrigation in Output Layer
# [[-0.07717783]
#  [ 0.05231003]
#  [ 0.03151657]
#  [ 0.1259881 ]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.48071511]
#  [0.51307453]
#  [0.50787849]
#  [0.53145543]]
# Error [[-0.48071511]
#  [ 0.48692547]
#  [ 0.49212151]
#  [-0.53145543]]
# ...
#  [0.51396402]
#  [0.54976745]]
# Error [[-0.45111159]
#  [ 0.48139948]
#  [ 0.48603598]
#  [-0.54976745]]
# Aggrigation in hidden layer
# [[0.65663759 0.28370121]
#  [1.62715998 1.57502785]
#  [1.66717453 1.35251194]
#  [2.63769692 2.64383859]]
#
# Applying Activation in Hidden layer
# [[0.65850467 0.57045339]
#  [0.83578021 0.82849919]
#  [0.84119875 0.79454   ]
#  [0.93324864 0.93363022]]
#
# Aggrigation in Output Layer
# [[-0.19636145]
#  [ 0.07451429]
#  [ 0.05595637]
#  [ 0.19987908]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.45106677]
#  [0.51861996]
#  [0.51398544]
#  [0.54980407]]
# Error [[-0.45106677]
#  [ 0.48138004]
#  [ 0.48601456]
#  [-0.54980407]]
# Aggrigation in hidden layer
# [[0.65658525 0.28377146]
#  [1.62758422 1.57565243]
#  [1.66758233 1.35331247]
#  [2.6385813  2.64519344]]
#
# Applying Activation in Hidden layer
# [[0.6584929  0.57047061]
#  [0.83583843 0.82858791]
#  [0.84125322 0.79467065]
#  [0.93330371 0.93371412]]
#
# Aggrigation in Output Layer
# [[-0.19654268]
#  [ 0.07459227]
#  [ 0.05604224]
#  [ 0.20002713]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.45102189]
#  [0.51863942]
#  [0.51400689]
#  [0.54984071]]
# Error [[-0.45102189]
#  [ 0.48136058]
#  [ 0.48599311]
#  [-0.54984071]]
# Aggrigation in hidden layer
# [[0.65653276 0.28384145]
#  [1.62800851 1.5762773 ]
#  [1.6679902  1.35411329]
#  [2.63946594 2.64654913]]
#
# Applying Activation in Hidden layer
# [[0.65848109 0.57048775]
#  [0.83589664 0.82867665]
#  [0.84130768 0.79480129]
#  [0.93335875 0.93379798]]
#
# Aggrigation in Output Layer
# [[-0.19672412]
#  [ 0.07467034]
#  [ 0.05612822]
#  [ 0.20017529]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.45097697]
#  [0.51865892]
#  [0.51402837]
#  [0.54987739]]
# Error [[-0.45097697]
#  [ 0.48134108]
#  [ 0.48597163]
#  [-0.54987739]]
# Aggrigation in hidden layer
# [[0.65648014 0.28391117]
#  [1.62843287 1.57690247]
#  [1.66839812 1.35491437]
#  [2.64035085 2.64790567]]
#
# Applying Activation in Hidden layer
# [[0.65846926 0.57050484]
#  [0.83595484 0.82876539]
#  [0.84136213 0.79493191]
#  [0.93341377 0.93388179]]
#
# Aggrigation in Output Layer
# [[-0.19690577]
#  [ 0.0747485 ]
#  [ 0.05621431]
#  [ 0.20032356]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.45093199]
#  [0.51867843]
#  [0.51404988]
#  [0.54991408]]
# Error [[-0.45093199]
#  [ 0.48132157]
#  [ 0.48595012]
#  [-0.54991408]]
# Aggrigation in hidden layer
# [[0.65642737 0.28398062]
#  [1.62885728 1.57752794]
#  [1.6688061  1.35571574]
#  [2.64123601 2.64926306]]
#
# Applying Activation in Hidden layer
# [[0.65845739 0.57052186]
#  [0.83601304 0.82885413]
#  [0.84141658 0.79506251]
#  [0.93346877 0.93396555]]
#
# Aggrigation in Output Layer
# [[-0.19708762]
#  [ 0.07482677]
#  [ 0.05630051]
#  [ 0.20047194]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.45088697]
#  [0.51869797]
#  [0.51407141]
#  [0.54995081]]
# Error [[-0.45088697]
#  [ 0.48130203]
#  [ 0.48592859]
#  [-0.54995081]]
# Aggrigation in hidden layer
# [[0.65637445 0.28404981]
#  [1.62928174 1.5781537 ]
#  [1.66921415 1.35651739]
#  [2.64212143 2.65062129]]
#
# Applying Activation in Hidden layer
# [[0.65844549 0.57053881]
#  [0.83607122 0.82894288]
#  [0.84147102 0.7951931 ]
#  [0.93352374 0.93404927]]
#
# Aggrigation in Output Layer
# [[-0.19726969]
#  [ 0.07490513]
#  [ 0.05638682]
#  [ 0.20062042]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.45084189]
#  [0.51871753]
#  [0.51409297]
#  [0.54998756]]
# Error [[-0.45084189]
#  [ 0.48128247]
#  [ 0.48590703]
#  [-0.54998756]]
# Aggrigation in hidden layer
# [[0.6563214  0.28411872]
#  [1.62970627 1.57877976]
#  [1.66962225 1.35731931]
#  [2.64300712 2.65198036]]
#
# Applying Activation in Hidden layer
# [[0.65843356 0.57055569]
#  [0.8361294  0.82903163]
#  [0.84152545 0.79532367]
#  [0.93357868 0.93413294]]
#
# Aggrigation in Output Layer
# [[-0.19745196]
#  [ 0.07498359]
#  [ 0.05647324]
#  [ 0.200769  ]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.45079676]
#  [0.51873712]
#  [0.51411456]
#  [0.55002433]]
# Error [[-0.45079676]
#  [ 0.48126288]
#  [ 0.48588544]
#  [-0.55002433]]
# Aggrigation in hidden layer
# [[0.6562682  0.28418735]
#  [1.63013085 1.57940612]
#  [1.67003041 1.35812151]
#  [2.64389306 2.65334028]]
#
# Applying Activation in Hidden layer
# [[0.65842159 0.57057251]
#  [0.83618756 0.82912039]
#  [0.84157988 0.79545422]
#  [0.93363359 0.93421657]]
#
# Aggrigation in Output Layer
# [[-0.19763445]
#  [ 0.07506215]
#  [ 0.05655977]
#  [ 0.20091769]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.45075159]
#  [0.51875673]
#  [0.51413617]
#  [0.55006113]]
# Error [[-0.45075159]
#  [ 0.48124327]
#  [ 0.48586383]
#  [-0.55006113]]
# Aggrigation in hidden layer
# [[0.65621485 0.28425572]
#  [1.63055548 1.58003276]
#  [1.67043864 1.35892399]
#  [2.64477926 2.65470104]]
#
# Applying Activation in Hidden layer
# [[0.6584096  0.57058926]
#  [0.83624572 0.82920916]
#  [0.84163429 0.79558476]
#  [0.93368848 0.93430015]]
#
# Aggrigation in Output Layer
# [[-0.19781714]
#  [ 0.07514081]
#  [ 0.0566464 ]
#  [ 0.20106649]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.45070636]
#  [0.51877637]
#  [0.51415782]
#  [0.55009796]]
# Error [[-0.45070636]
#  [ 0.48122363]
#  [ 0.48584218]
#  [-0.55009796]]
# Aggrigation in hidden layer
# [[0.65616137 0.28432381]
#  [1.63098017 1.5806597 ]
#  [1.67084692 1.35972674]
#  [2.64566572 2.65606264]]
#
# Applying Activation in Hidden layer
# [[0.65839757 0.57060594]
#  [0.83630387 0.82929793]
#  [0.8416887  0.79571528]
#  [0.93374335 0.93438368]]
#
# Aggrigation in Output Layer
# [[-0.19800004]
#  [ 0.07521956]
#  [ 0.05673315]
#  [ 0.20121539]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.45066107]
#  [0.51879603]
#  [0.51417949]
#  [0.55013481]]
# Error [[-0.45066107]
#  [ 0.48120397]
#  [ 0.48582051]
#  [-0.55013481]]
# Aggrigation in hidden layer
# [[0.65610774 0.28439163]
#  [1.63140492 1.58128694]
#  [1.67125526 1.36052977]
#  [2.64655244 2.65742508]]
#
# Applying Activation in Hidden layer
# [[0.6583855  0.57062256]
#  [0.83636201 0.8293867 ]
#  [0.84174311 0.79584579]
#  [0.93379818 0.93446716]]
#
# Aggrigation in Output Layer
# [[-0.19818316]
#  [ 0.07529841]
#  [ 0.05682001]
#  [ 0.2013644 ]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.45061574]
#  [0.51881571]
#  [0.51420118]
#  [0.55017169]]
# Error [[-0.45061574]
#  [ 0.48118429]
#  [ 0.48579882]
#  [-0.55017169]]
# Aggrigation in hidden layer
# [[0.65605397 0.28445917]
#  [1.63182973 1.58191447]
#  [1.67166366 1.36133307]
#  [2.64743942 2.65878837]]
#
# Applying Activation in Hidden layer
# [[0.65837341 0.57063911]
#  [0.83642014 0.82947548]
#  [0.8417975  0.79597627]
#  [0.93385299 0.9345506 ]]
#
# Aggrigation in Output Layer
# [[-0.19836648]
#  [ 0.07537736]
#  [ 0.05690698]
#  [ 0.20151352]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.45057036]
#  [0.51883542]
#  [0.51422291]
#  [0.55020859]]
# Error [[-0.45057036]
#  [ 0.48116458]
#  [ 0.48577709]
#  [-0.55020859]]
# Aggrigation in hidden layer
# [[0.65600005 0.28452643]
#  [1.63225459 1.58254228]
#  [1.67207212 1.36213664]
#  [2.64832665 2.66015249]]
#
# Applying Activation in Hidden layer
# [[0.65836128 0.57065559]
#  [0.83647826 0.82956427]
#  [0.84185189 0.79610674]
#  [0.93390778 0.93463398]]
#
# Aggrigation in Output Layer
# [[-0.19855002]
#  [ 0.07545641]
#  [ 0.05699406]
#  [ 0.20166274]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.45052492]
#  [0.51885516]
#  [0.51424466]
#  [0.55024552]]
# Error [[-0.45052492]
#  [ 0.48114484]
#  [ 0.48575534]
#  [-0.55024552]]
# Aggrigation in hidden layer
# [[0.65594599 0.28459342]
#  [1.6326795  1.58317039]
#  [1.67248063 1.36294048]
#  [2.64921415 2.66151746]]
#
# Applying Activation in Hidden layer
# [[0.65834912 0.570672  ]
#  [0.83653637 0.82965305]
#  [0.84190627 0.79623719]
#  [0.93396254 0.93471732]]
#
# Aggrigation in Output Layer
# [[-0.19873376]
#  [ 0.07553556]
#  [ 0.05708125]
#  [ 0.20181207]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.45047944]
#  [0.51887492]
#  [0.51426644]
#  [0.55028247]]
# Error [[-0.45047944]
#  [ 0.48112508]
#  [ 0.48573356]
#  [-0.55028247]]
# Aggrigation in hidden layer
# [[0.65589178 0.28466013]
#  [1.63310447 1.5837988 ]
#  [1.67288921 1.3637446 ]
#  [2.6501019  2.66288327]]
#
# Applying Activation in Hidden layer
# [[0.65833693 0.57068834]
#  [0.83659448 0.82974185]
#  [0.84196065 0.79636762]
#  [0.93401727 0.93480062]]
#
# Aggrigation in Output Layer
# [[-0.19891772]
#  [ 0.07561481]
#  [ 0.05716855]
#  [ 0.2019615 ]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.4504339 ]
#  [0.5188947 ]
#  [0.51428825]
#  [0.55031945]]
# Error [[-0.4504339 ]
#  [ 0.4811053 ]
#  [ 0.48571175]
#  [-0.55031945]]
# Aggrigation in hidden layer
# [[0.65583743 0.28472656]
#  [1.63352949 1.58442749]
#  [1.67329784 1.36454899]
#  [2.6509899  2.66424991]]
#
# Applying Activation in Hidden layer
# [[0.65832471 0.57070462]
#  [0.83665257 0.82983064]
#  [0.84201501 0.79649803]
#  [0.93407198 0.93488386]]
#
# Aggrigation in Output Layer
# [[-0.19910189]
#  [ 0.07569415]
#  [ 0.05725595]
#  [ 0.20211104]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.45038831]
#  [0.51891451]
#  [0.51431008]
#  [0.55035646]]
# Error [[-0.45038831]
#  [ 0.48108549]
#  [ 0.48568992]
#  [-0.55035646]]
# Aggrigation in hidden layer
# [[0.65578294 0.28479271]
#  [1.63395457 1.58505647]
#  [1.67370653 1.36535364]
#  [2.65187817 2.6656174 ]]
#
# Applying Activation in Hidden layer
# [[0.65831245 0.57072083]
#  [0.83671066 0.82991945]
#  [0.84206937 0.79662843]
#  [0.93412666 0.93496706]]
#
# Aggrigation in Output Layer
# [[-0.19928627]
#  [ 0.07577359]
#  [ 0.05734347]
#  [ 0.20226069]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.45034267]
#  [0.51893434]
#  [0.51433194]
#  [0.55039349]]
# Error [[-0.45034267]
#  [ 0.48106566]
#  [ 0.48566806]
#  [-0.55039349]]
# Aggrigation in hidden layer
# [[0.6557283  0.28485858]
#  [1.63437971 1.58568574]
#  [1.67411528 1.36615857]
#  [2.65276669 2.66698572]]
#
# Applying Activation in Hidden layer
# [[0.65830016 0.57073697]
#  [0.83676873 0.83000825]
#  [0.84212372 0.7967588 ]
#  [0.93418131 0.93505021]]
#
# Aggrigation in Output Layer
# [[-0.19947087]
#  [ 0.07585314]
#  [ 0.05743111]
#  [ 0.20241045]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.45029697]
#  [0.5189542 ]
#  [0.51435383]
#  [0.55043055]]
# Error [[-0.45029697]
#  [ 0.4810458 ]
#  [ 0.48564617]
#  [-0.55043055]]
# Aggrigation in hidden layer
# [[0.65567352 0.28492417]
#  [1.6348049  1.5863153 ]
#  [1.67452409 1.36696376]
#  [2.65365546 2.66835489]]
#
# Applying Activation in Hidden layer
# [[0.65828784 0.57075303]
#  [0.8368268  0.83009706]
#  [0.84217807 0.79688916]
#  [0.93423594 0.93513331]]
#
# Aggrigation in Output Layer
# [[-0.19965568]
#  [ 0.07593278]
#  [ 0.05751885]
#  [ 0.20256031]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.45025123]
#  [0.51897408]
#  [0.51437575]
#  [0.55046763]]
# Error [[-0.45025123]
#  [ 0.48102592]
#  [ 0.48562425]
#  [-0.55046763]]
# Aggrigation in hidden layer
# [[0.65561859 0.28498948]
#  [1.63523014 1.58694514]
#  [1.67493295 1.36776922]
#  [2.6545445  2.66972489]]
#
# Applying Activation in Hidden layer
# [[0.65827548 0.57076903]
#  [0.83688486 0.83018587]
#  [0.8422324  0.7970195 ]
#  [0.93429054 0.93521637]]
#
# Aggrigation in Output Layer
# [[-0.19984069]
#  [ 0.07601252]
#  [ 0.0576067 ]
#  [ 0.20271027]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.45020543]
#  [0.51899398]
#  [0.51439769]
#  [0.55050474]]
# Error [[-0.45020543]
#  [ 0.48100602]
#  [ 0.48560231]
#  [-0.55050474]]
# Aggrigation in hidden layer
# [[0.65556352 0.2850545 ]
#  [1.63565543 1.58757528]
#  [1.67534187 1.36857495]
#  [2.65543378 2.67109573]]
#
# Applying Activation in Hidden layer
# [[0.65826309 0.57078496]
#  [0.8369429  0.83027469]
#  [0.84228673 0.79714982]
#  [0.93434511 0.93529937]]
#
# Aggrigation in Output Layer
# [[-0.20002593]
#  [ 0.07609236]
#  [ 0.05769466]
#  [ 0.20286035]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.45015959]
#  [0.51901392]
#  [0.51441967]
#  [0.55054188]]
# Error [[-0.45015959]
#  [ 0.48098608]
#  [ 0.48558033]
#  [-0.55054188]]
# Aggrigation in hidden layer
# [[0.6555083  0.28511924]
#  [1.63608078 1.5882057 ]
#  [1.67575085 1.36938095]
#  [2.65632333 2.6724674 ]]
#
# Applying Activation in Hidden layer
# [[0.65825067 0.57080082]
#  [0.83700094 0.83036351]
#  [0.84234105 0.79728012]
#  [0.93439966 0.93538233]]
#
# Aggrigation in Output Layer
# [[-0.20021137]
#  [ 0.0761723 ]
#  [ 0.05778274]
#  [ 0.20301053]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.45011369]
#  [0.51903387]
#  [0.51444167]
#  [0.55057904]]
# Error [[-0.45011369]
#  [ 0.48096613]
#  [ 0.48555833]
#  [-0.55057904]]
# Aggrigation in hidden layer
# [[0.65545294 0.2851837 ]
#  [1.63650619 1.5888364 ]
#  [1.67615988 1.37018721]
#  [2.65721313 2.67383991]]
#
# Applying Activation in Hidden layer
# [[0.65823822 0.57081662]
#  [0.83705897 0.83045233]
#  [0.84239537 0.7974104 ]
#  [0.93445418 0.93546524]]
#
# Aggrigation in Output Layer
# [[-0.20039703]
#  [ 0.07625233]
#  [ 0.05787092]
#  [ 0.20316081]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.45006773]
#  [0.51905385]
#  [0.51446369]
#  [0.55061623]]
# Error [[-0.45006773]
#  [ 0.48094615]
#  [ 0.48553631]
#  [-0.55061623]]
# Aggrigation in hidden layer
# [[0.65539744 0.28524786]
#  [1.63693164 1.58946739]
#  [1.67656897 1.37099373]
#  [2.65810318 2.67521326]]
#
# Applying Activation in Hidden layer
# [[0.65822573 0.57083234]
#  [0.83711699 0.83054116]
#  [0.84244967 0.79754066]
#  [0.93450867 0.93554809]]
#
# Aggrigation in Output Layer
# [[-0.2005829 ]
#  [ 0.07633247]
#  [ 0.05795922]
#  [ 0.20331121]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.45002173]
#  [0.51907386]
#  [0.51448575]
#  [0.55065344]]
# Error [[-0.45002173]
#  [ 0.48092614]
#  [ 0.48551425]
#  [-0.55065344]]
# Aggrigation in hidden layer
# [[0.65534178 0.28531175]
#  [1.63735715 1.59009867]
#  [1.67697811 1.37180052]
#  [2.65899348 2.67658744]]
#
# Applying Activation in Hidden layer
# [[0.65821321 0.57084799]
#  [0.837175   0.83062998]
#  [0.84250397 0.7976709 ]
#  [0.93456314 0.93563091]]
#
# Aggrigation in Output Layer
# [[-0.20076899]
#  [ 0.07641271]
#  [ 0.05804763]
#  [ 0.20346171]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.44997567]
#  [0.51909389]
#  [0.51450783]
#  [0.55069068]]
# Error [[-0.44997567]
#  [ 0.48090611]
#  [ 0.48549217]
#  [-0.55069068]]
# Aggrigation in hidden layer
# [[0.65528599 0.28537534]
#  [1.63778272 1.59073023]
#  [1.67738732 1.37260757]
#  [2.65988405 2.67796246]]
#
# Applying Activation in Hidden layer
# [[0.65820066 0.57086356]
#  [0.83723301 0.83071882]
#  [0.84255826 0.79780112]
#  [0.93461758 0.93571367]]
#
# Aggrigation in Output Layer
# [[-0.20095529]
#  [ 0.07649305]
#  [ 0.05813615]
#  [ 0.20361231]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.44992956]
#  [0.51911394]
#  [0.51452994]
#  [0.55072794]]
# Error [[-0.44992956]
#  [ 0.48088606]
#  [ 0.48547006]
#  [-0.55072794]]
# Aggrigation in hidden layer
# [[0.65523004 0.28543865]
#  [1.63820833 1.59136208]
#  [1.67779657 1.37341488]
#  [2.66077486 2.67933831]]
#
# Applying Activation in Hidden layer
# [[0.65818807 0.57087907]
#  [0.837291   0.83080765]
#  [0.84261254 0.79793132]
#  [0.934672   0.93579638]]
#
# Aggrigation in Output Layer
# [[-0.20114181]
#  [ 0.07657348]
#  [ 0.05822478]
#  [ 0.20376303]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.4498834 ]
#  [0.51913402]
#  [0.51455208]
#  [0.55076523]]
# Error [[-0.4498834 ]
#  [ 0.48086598]
#  [ 0.48544792]
#  [-0.55076523]]
# Aggrigation in hidden layer
# [[0.65517396 0.28550166]
#  [1.638634   1.5919942 ]
#  [1.67820589 1.37422246]
#  [2.66166593 2.680715  ]]
#
# Applying Activation in Hidden layer
# [[0.65817545 0.57089451]
#  [0.83734898 0.83089649]
#  [0.84266681 0.7980615 ]
#  [0.93472638 0.93587904]]
#
# Aggrigation in Output Layer
# [[-0.20132854]
#  [ 0.07665402]
#  [ 0.05831352]
#  [ 0.20391385]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.44983719]
#  [0.51915413]
#  [0.51457425]
#  [0.55080255]]
# Error [[-0.44983719]
#  [ 0.48084587]
#  [ 0.48542575]
#  [-0.55080255]]
# Aggrigation in hidden layer
# [[0.65511772 0.28556439]
#  [1.63905972 1.59262661]
#  [1.67861525 1.37503029]
#  [2.66255725 2.68209252]]
#
# Applying Activation in Hidden layer
# [[0.6581628  0.57090988]
#  [0.83740695 0.83098533]
#  [0.84272108 0.79819166]
#  [0.93478074 0.93596166]]
#
# Aggrigation in Output Layer
# [[-0.20151548]
#  [ 0.07673466]
#  [ 0.05840237]
#  [ 0.20406478]]
#
# Applying Activation Function in Output layer
# Predicated Output
# [[0.44979092]
#  [0.51917426]
#  [0.51459644]
#  [0.55083989]]
# Error [[-0.44979092]
#  [ 0.48082574]
#  [ 0.48540356]
#  [-0.55083989]]

# %%
print("Hidden layer Weights")
print(HW)
print("")

print("Hidden layer bias")
print(hidden_bias)
print("")

print("Output layer Weights")
print(OW)
print("")

print("Output layer bias")
print(output_bias)
print("")
# Out:
# Hidden layer Weights
# [[1.02396333 1.09021156]
#  [0.98442414 1.30763248]]
#
# Hidden layer bias
# [[0.65506134 0.28562683]]
#
# Output layer Weights
# [[0.60033774]
#  [0.65681051]]
#
# Output layer bias
# [[-0.97180465]]

# %%
print(Predicted_Output)
# Out:
# [[0.44979092]
#  [0.51917426]
#  [0.51459644]
#  [0.55083989]]
